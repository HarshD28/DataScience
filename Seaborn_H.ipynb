# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.set()

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
veh = pd.read_csv("F:\Data Science Course\Harsh\car data.csv")

# %%
veh.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
sns.relplot(x="Selling_Price" , y="Present_Price" , data=veh)

# %%
sns.relplot(x="Selling_Price" , y="Present_Price" , data=veh , hue ="Kms_Driven")

# %%
sns.relplot(x="Selling_Price" , y="Fuel_Type" , data=veh)

# %%
sns.relplot(x="Selling_Price" , y="Present_Price" , data=veh , style="Fuel_Type")

# %%
sns.relplot(x="Selling_Price" , y="Present_Price" , data=veh , style="Fuel_Type" , hue="Year")

# %%
sns.relplot(x="Selling_Price" , y="Present_Price" , data=veh , style="Fuel_Type" , hue="Transmission")

# %%
sns.relplot(x="Selling_Price" , y="Present_Price" , data=veh , style="Fuel_Type" , col="Transmission")

# %%
sns.relplot(x="Selling_Price" , y="Present_Price" , data=veh , style="Fuel_Type" , col="Transmission" , col_wrap=1)

# %%
sns.relplot(x="Selling_Price" , y="Present_Price" , data=veh , hue="Fuel_Type" , palette='ch:s=0.7 , r=0.95')

# %%
sns.relplot(x="Selling_Price" , y="Present_Price" , data=veh , size="Fuel_Type" , sizes=(1,200))

# %%
fmri=sns.load_dataset("fmri")
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %% [markdown]
# SCATTERPLOT

# %%
sns.scatterplot(x="Selling_Price" , y="Present_Price" , data=veh)

# %%
sns.relplot(x="Selling_Price" , y="Present_Price" , data=veh , hue="Fuel_Type")

# %%
sns.relplot(x="Selling_Price" , y="Present_Price" , data=veh , hue="Year")

# %%
sns.relplot(x="Selling_Price" , y="Present_Price" , data=veh , hue="Fuel_Type" , size="Kms_Driven")

# %%
sns.relplot(x="Selling_Price" , y="Present_Price" , data=veh , style="Fuel_Type" , size="Transmission")

# %% [markdown]
# catplot

# %%
sns.catplot(x="Selling_Price" , y="Present_Price" , data=veh)

# %%
sns.catplot(y="Selling_Price" , x="Present_Price" , data=veh)

# %%
sns.catplot(x="Transmission" , y="Present_Price" , data=veh)

# %%
sns.catplot(x="Transmission" , y="Present_Price" , data=veh , jitter= False)

# %%
sns.catplot(x="Transmission" , y="Present_Price" , data=veh , kind="swarm")

# %%
sns.catplot(x="Fuel_Type" , y="Present_Price" , data=veh , kind="swarm" ,hue="Transmission")

# %%
sns.catplot(x="Fuel_Type" , y="Present_Price" , data=veh , kind="box" ,hue="Transmission")
