# %%
import pandas as pd

# %%
df=pd.read_csv("F:\Data Science Course\Harsh\car data.csv")

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.head(25)
# Out:
#          Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0            ritz  2014           3.35           5.59       27000    Petrol
# 1             sx4  2013           4.75           9.54       43000    Diesel
# 2            ciaz  2017           7.25           9.85        6900    Petrol
# 3         wagon r  2011           2.85           4.15        5200    Petrol
# 4           swift  2014           4.60           6.87       42450    Diesel
# 5   vitara brezza  2018           9.25           9.83        2071    Diesel
# 6            ciaz  2015           6.75           8.12       18796    Petrol
# 7         s cross  2015           6.50           8.61       33429    Diesel
# 8            ciaz  2016           8.75           8.89       20273    Diesel
# 9            ciaz  2015           7.45           8.92       42367    Diesel
# 10       alto 800  2017           2.85           3.60        2135    Petrol
# ...

# %%
df.tail(5)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
df=pd.read_csv("F:\Data Science Course\Harsh\car data.csv", nrows= 25)
df
# Out:
#          Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0            ritz  2014           3.35           5.59       27000    Petrol
# 1             sx4  2013           4.75           9.54       43000    Diesel
# 2            ciaz  2017           7.25           9.85        6900    Petrol
# 3         wagon r  2011           2.85           4.15        5200    Petrol
# 4           swift  2014           4.60           6.87       42450    Diesel
# 5   vitara brezza  2018           9.25           9.83        2071    Diesel
# 6            ciaz  2015           6.75           8.12       18796    Petrol
# 7         s cross  2015           6.50           8.61       33429    Diesel
# 8            ciaz  2016           8.75           8.89       20273    Diesel
# 9            ciaz  2015           7.45           8.92       42367    Diesel
# 10       alto 800  2017           2.85           3.60        2135    Petrol
# ...

# %%
df=pd.read_csv("F:\Data Science Course\Harsh\car data.csv")
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %%
df['Car_Name']
# Out:
# 0         ritz
# 1          sx4
# 2         ciaz
# 3      wagon r
# 4        swift
#         ...
# 296       city
# 297       brio
# 298       city
# 299       city
# 300       brio
# Name: Car_Name, Length: 301, dtype: object

# %%
list(df['Car_Name'])
# Out:
# ['ritz',
#  'sx4',
#  'ciaz',
#  'wagon r',
#  'swift',
#  'vitara brezza',
#  'ciaz',
#  's cross',
#  'ciaz',
#  'ciaz',
#  'alto 800',
#  'ciaz',
#  'ciaz',
#  'ertiga',
#  'dzire',
#  'ertiga',
#  'ertiga',
#  'ertiga',
#  'wagon r',
#  'sx4',
#  'alto k10',
#  'ignis',
#  'sx4',
#  'alto k10',
#  'wagon r',
#  'swift',
#  'swift',
#  'swift',
#  'alto k10',
#  'ciaz',
#  'ritz',
#  'ritz',
#  'swift',
#  'ertiga',
#  'dzire',
#  'sx4',
#  'dzire',
#  '800',
#  'alto k10',
#  'sx4',
#  'baleno',
#  'alto k10',
#  'sx4',
#  'dzire',
#  'omni',
#  'ciaz',
#  'ritz',
#  'wagon r',
#  'ertiga',
#  'ciaz',
#  'fortuner',
#  'fortuner',
#  'innova',
#  'fortuner',
#  'innova',
#  'corolla altis',
#  'etios cross',
#  'corolla altis',
#  'etios g',
#  'fortuner',
#  'corolla altis',
#  'etios cross',
#  'fortuner',
#  'fortuner',
#  'fortuner',
#  'etios liva',
#  'innova',
#  'fortuner',
#  'corolla altis',
#  'corolla altis',
#  'etios liva',
#  'corolla altis',
#  'corolla altis',
# ...

# %%
type(df['Car_Name'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['Year'][5]
# Out:
# 2018

# %%
df[['Present_Price']]
# Out:
#      Present_Price
# 0             5.59
# 1             9.54
# 2             9.85
# 3             4.15
# 4             6.87
# ..             ...
# 296          11.60
# 297           5.90
# 298          11.00
# 299          12.50
# 300           5.90
#
# [301 rows x 1 columns]

# %%
print(type(df[['Car_Name']]))
print(type(df['Car_Name']))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
df[['Car_Name','Present_Price','Kms_Driven']]
# Out:
#     Car_Name  Present_Price  Kms_Driven
# 0       ritz           5.59       27000
# 1        sx4           9.54       43000
# 2       ciaz           9.85        6900
# 3    wagon r           4.15        5200
# 4      swift           6.87       42450
# ..       ...            ...         ...
# 296     city          11.60       33988
# 297     brio           5.90       60000
# 298     city          11.00       87934
# 299     city          12.50        9000
# 300     brio           5.90        5464
#
# [301 rows x 3 columns]

# %%
pd.read_csv("F:\Data Science Course\Harsh\car data.csv", nrows=20)
# Out:
#          Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0            ritz  2014           3.35           5.59       27000    Petrol
# 1             sx4  2013           4.75           9.54       43000    Diesel
# 2            ciaz  2017           7.25           9.85        6900    Petrol
# 3         wagon r  2011           2.85           4.15        5200    Petrol
# 4           swift  2014           4.60           6.87       42450    Diesel
# 5   vitara brezza  2018           9.25           9.83        2071    Diesel
# 6            ciaz  2015           6.75           8.12       18796    Petrol
# 7         s cross  2015           6.50           8.61       33429    Diesel
# 8            ciaz  2016           8.75           8.89       20273    Diesel
# 9            ciaz  2015           7.45           8.92       42367    Diesel
# 10       alto 800  2017           2.85           3.60        2135    Petrol
# ...

# %%
df=pd.read_csv("F:\Data Science Course\Harsh\car data.csv", nrows=5,header=None)
df
# Out:
#           0     1              2              3           4          5  \
# 0  Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type
# 1      ritz  2014           3.35           5.59       27000     Petrol
# 2       sx4  2013           4.75           9.54       43000     Diesel
# 3      ciaz  2017           7.25           9.85        6900     Petrol
# 4   wagon r  2011           2.85           4.15        5200     Petrol
#
#              6             7      8
# 0  Seller_Type  Transmission  Owner
# 1       Dealer        Manual      0
# 2       Dealer        Manual      0
# 3       Dealer        Manual      0
# 4       Dealer        Manual      0

# %%
df[5]
# Out:
# 0    Fuel_Type
# 1       Petrol
# 2       Diesel
# 3       Petrol
# 4       Petrol
# Name: 5, dtype: object

# %%
c=pd.read_csv("F:\Data Science Course\Harsh\car data.csv", nrows=5,header=None,skiprows=5)
c
# Out:
#                0     1     2     3      4       5       6       7  8
# 0          swift  2014  4.60  6.87  42450  Diesel  Dealer  Manual  0
# 1  vitara brezza  2018  9.25  9.83   2071  Diesel  Dealer  Manual  0
# 2           ciaz  2015  6.75  8.12  18796  Petrol  Dealer  Manual  0
# 3        s cross  2015  6.50  8.61  33429  Diesel  Dealer  Manual  0
# 4           ciaz  2016  8.75  8.89  20273  Diesel  Dealer  Manual  0

# %%
c= pd.read_csv("F:\Data Science Course\Harsh\car data.csv", nrows=5, header=None, names=['h','a','r','s','d','u','b','e','y'])
c
# Out:
#           h     a              r              s           d          u  \
# 0  Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type
# 1      ritz  2014           3.35           5.59       27000     Petrol
# 2       sx4  2013           4.75           9.54       43000     Diesel
# 3      ciaz  2017           7.25           9.85        6900     Petrol
# 4   wagon r  2011           2.85           4.15        5200     Petrol
#
#              b             e      y
# 0  Seller_Type  Transmission  Owner
# 1       Dealer        Manual      0
# 2       Dealer        Manual      0
# 3       Dealer        Manual      0
# 4       Dealer        Manual      0

# %%
df=pd.read_csv("F:\Data Science Course\Harsh\car data.csv", index_col=["Selling_Price"])
df
# Out:
#               Car_Name  Year  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# Selling_Price
# 3.35              ritz  2014           5.59       27000    Petrol      Dealer
# 4.75               sx4  2013           9.54       43000    Diesel      Dealer
# 7.25              ciaz  2017           9.85        6900    Petrol      Dealer
# 2.85           wagon r  2011           4.15        5200    Petrol      Dealer
# 4.60             swift  2014           6.87       42450    Diesel      Dealer
# ...                ...   ...            ...         ...       ...         ...
# 9.50              city  2016          11.60       33988    Diesel      Dealer
# 4.00              brio  2015           5.90       60000    Petrol      Dealer
# 3.35              city  2009          11.00       87934    Petrol      Dealer
# 11.50             city  2017          12.50        9000    Diesel      Dealer
# 5.30              brio  2016           5.90        5464    Petrol      Dealer
#
# ...
